# %% [markdown]
# <a href="https://colab.research.google.com/github/Eunjane/J-sMathematical.github.io-/blob/main/R%20program%20lab7_LastName.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 7: Data Visualization (20 points)**
#
# #### **WRITE YOUR NAME HERE**

# %% [markdown]
# ---
# **Instructions**: Complete the lab below.
# - <font color=red>Tasks</font> indicated in red must be completed to receive credit
# - Include all code for your work
# - Include markdown cells with written answers explaining your work when prompted
# - **NOTE: Your completed lab must be submitted to Canvas as a .ipynb file by the end of the lab session**
# ---

# %% [markdown]
# <br>

# %% [markdown]
# ####<font color=red>Organized</font> (1 points)
# * Answers should be organized in the following format for organization and readability
#
# <br>
#
# ```
# # 1.
# This will be the code block to answer the first part of a task
# ```
#
# 1. This will be the text answer/explanation (if prompted) for the first task
#
# ```
# # 2.
# This will be the code block to answer the second part of a task in a separate code cell
# ```
#
# 2. This will be the text answer/explanation (if prompted) for the second task
#
# <br>
#
# Continue this format for the remaining subtasks

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 1</font>  (4 points)
#
# Load the COPD dataset available [here](https://raw.githubusercontent.com/khasenst/datasets_teaching/main/copd_data_project.csv) as dataframe called `copd`
#
# Explore the dataset using boxplots.
# 1. Create a boxplot that interests you (and your group), and interpret your findings in complete sentences.
# 2. Create a second boxplot that interests you (and your group), using different variables from Task 1.1 and interpret your findings in complete sentences.
#
# Try to spend some time on this. In reality, you explore dozens of these plots to understand patterns within the data

# %%
#!
copd <- read.csv("https://raw.githubusercontent.com/khasenst/datasets_teaching/main/copd_data_project.csv")
head(copd)
# Out:
#   sid    visit_year visit_date visit_age gender race  height_cm weight_kg sysBP
# 1 10005Q 2008       1/15/2008  54.5      Female White 159.9      73.0     130
# 2 10006S 2008       1/15/2008  62.3      Female White 162.6      86.0     170
# 3 10010J 2008       1/15/2008  65.9      Female White 162.1      62.8      96
# 4 10015T 2008       2/15/2008  59.6      Male   White 182.9     110.0     142
# 5 10017X 2008       6/15/2008  67.5      Male   White 179.1      83.0     106
# 6 10022Q 2008       2/15/2008  69.8      Female White 158.8      78.0     122
#   diasBP ⋯ total_lung_capacity pct_emphysema functional_residual_capacity
# 1 80     ⋯ 5.6636               0.926851      2.4766
# 2 80     ⋯ 5.2325              14.005900     -1.0000
# 3 63     ⋯ 5.1960               1.683760      3.8993
# 4 88     ⋯ 6.3971               9.330450     -1.0000
# 5 72     ⋯ 7.8935              36.262400      4.1043
# 6 78     ⋯ 5.1016              30.484400     -1.0000
# ...

# %%
names(copd)
# Out:
#  [1] "sid"                          "visit_year"
#  [3] "visit_date"                   "visit_age"
#  [5] "gender"                       "race"
#  [7] "height_cm"                    "weight_kg"
#  [9] "sysBP"                        "diasBP"
# [11] "hr"                           "O2_hours_day"
# [13] "bmi"                          "asthma"
# [15] "hay_fever"                    "bronchitis_attack"
# [17] "pneumonia"                    "chronic_bronchitis"
# [19] "emphysema"                    "copd"
# [21] "sleep_apnea"                  "SmokStartAge"
# [23] "CigPerDaySmokAvg"             "Duration_Smoking"
# [25] "smoking_status"               "total_lung_capacity"
# [27] "pct_emphysema"                "functional_residual_capacity"
# [29] "pct_gastrapping"              "insp_meanatt"
# [31] "exp_meanatt"                  "FEV1_FVC_ratio"
# [33] "FEV1"                         "FVC"
# [35] "FEV1_phase2"

# %%
#1.1
boxplot(copd$CigPerDaySmokAvg ~ copd$gender)
# Out:
# plot without title

# %% [markdown]
# 1.1 Female has more higher range of per day of smoking than male. Male who had high per day smoking age had outlier.

# %%
#1.2
boxplot(copd$bmi ~ copd$gender)
# Out:
# plot without title

# %% [markdown]
# 1.2 Females have the big range of bmi than males. Bmi for females have more high bmi oultiers.

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 2</font>  (10 points)
#
# Create a **TWO** scatterplots, each with 3 of the 5 following attributes. Interpret the results of the two plots in complete sentences.
#
# Note that the first attribute is required.
#
# 1. Scatterplot showing the relationship between two continuous variables (y-axis vs x-axis)
# 2. Color dimension to describe the value/category of another variable
# 3. Shape dimension to describe the shape/category of another variable
# 4. Size dimension to describe the valuecategory of another variable
# 5. Annotatation that labels the points based on the value/categories of another variable

# %%
#2.1
options(repr.plot.width=10, repr.plot.height=15)
g <- ggplot(copd,aes(x=SmokStartAge, y=total_lung_capacity)) + 
             geom_point(aes(size = weight_kg, color = emphysema),alpha=0.5)
 g
# Out:
# plot without title

# %%
#2.2
g <- ggplot(copd,aes(x=pct_emphysema, y=bmi)) + 
             geom_point(aes(size = weight_kg, color = emphysema),alpha=0.5)
 g
# Out:
# plot without title

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ####<font color=red>Task 3</font>  (5 points)
#
# Each group must present their findings by the end of lab.
